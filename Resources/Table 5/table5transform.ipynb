# %%
import pandas as pd
from datetime import datetime as dt

# %%
wmt_csv = "wmt_csv.csv"
amz_csv = "amzn_csv.csv"
cos_csv = "cost_csv.csv"
tgt_csv = "tgt_csv.csv"
wmt_df = pd.read_csv(wmt_csv)
amz_df = pd.read_csv(amz_csv)
cos_df = pd.read_csv(cos_csv)
tgt_df = pd.read_csv(tgt_csv)
# Out:
#       Date  Revenue USD Mil  Gross Margin %  Operating Income USD Mil  \
# 0  2011-01            67390            30.9                      5252
# 1  2012-01            69865            30.9                      5322
# 2  2013-01            73301            30.4                      5210
# 3  2014-01            72596            29.5                      3838
# 4  2015-01            72618            29.4                      4535
# 5  2016-01            73785            29.5                      4910
# 6  2017-01            69495            29.7                      4969
# 7  2018-01            71879            28.9                      4312
# 8  2019-01            75356            29.3                      4110
# 9  2020-01            78112            29.8                      4658
#
#    Operating Margin %  Net Income USD Mil  Earnings Per Share USD  \
# 0                 7.8                2920                    4.00
# 1                 7.6                2929                    4.28
# 2                 7.1                2999                    4.52
# 3                 5.3                1971                    3.07
# 4                 6.2               -1636                   -2.58
# 5                 6.7                3363                    5.31
# 6                 7.2                2737                    4.69
# 7                 6.0                2934                    5.29
# 8                 5.5                2937                    5.51
# 9                 6.0                3281                    6.36
#
#    Dividends USD  Payout Ratio % *  Shares Mil  Book Value Per Share * USD  \
# 0           0.84              21.0         729                       22.00
# 1           1.10              25.7         683                       23.64
# 2           1.32              28.0         663                       25.13
# 3           1.58              40.6         641                       25.56
# 4           1.90              76.0         640                       25.57
# 5           2.16              47.0         632                       22.01
# 6           2.32              42.1         583                       19.90
# 7           2.44              50.9         550                       20.49
# 8           2.52              41.7         533                       21.23
# 9           2.60              41.4         516                       22.78
#
#    Operating Cash Flow USD Mil  Cap Spending USD Mil  Free Cash Flow USD Mil  \
# 0                         5271                 -2129                    3142
# 1                         5434                 -4368                    1066
# 2                         5325                 -3277                    2048
# 3                         6520                 -3453                    3067
# 4                         4439                 -1786                    2653
# 5                         5844                 -1438                    4406
# 6                         5436                 -1547                    3889
# 7                         6923                 -2533                    4390
# 8                         5973                 -3516                    2457
# 9                         7117                 -3027                    4090
#
#    Free Cash Flow Per Share * USD  Working Capital USD Mil
# 0                            4.31                     7143
# 1                            1.56                     2162
# 2                            4.27                     2357
# 3                            4.57                    -1204
# 4                            2.56                     2351
# 5                            7.18                     1508
# 6                            5.70                     -718
# 7                            8.35                     -637
# 8                            5.00                    -2495
# 9                            6.67                    -1585

# %%
wmt_df = wmt_df.dropna(axis=1, how='any')
amz_df = amz_df.dropna(axis=1, how='any')
cos_df = cos_df.dropna(axis=1, how='any')
tgt_df = wmt_df.dropna(axis=1, how='any')

# %%
wmt_df['Date'] = pd.to_datetime(wmt_df['Date'],format='%Y-%m').dt.strftime('%Y')
amz_df['Date'] = pd.to_datetime(amz_df['Date'],format='%Y-%m').dt.strftime('%Y')
tgt_df['Date'] = pd.to_datetime(tgt_df['Date'],format='%Y-%m').dt.strftime('%Y')
cos_df['Date'] = pd.to_datetime(cos_df['Date'],format='%Y-%m').dt.strftime('%Y')

# %%
tgt_df
# Out:
#    Date  Revenue USD Mil  Gross Margin %  Operating Income USD Mil  \
# 0  2010           408214            25.4                     23950
# 1  2011           421849            25.3                     25542
# 2  2012           446950            25.0                     26558
# 3  2013           469162            24.9                     27801
# 4  2014           476294            24.8                     26872
# 5  2015           485651            24.8                     27147
# 6  2016           482130            25.1                     24105
# 7  2017           485873            25.6                     22764
# 8  2018           500343            25.4                     20437
# 9  2019           514405            25.1                     21957
#
#    Operating Margin %  Net Income USD Mil  Earnings Per Share USD  \
# 0                 5.9               14335                    3.71
# 1                 6.1               16389                    4.47
# 2                 5.9               15699                    4.52
# 3                 5.9               16999                    5.02
# 4                 5.6               16022                    4.88
# 5                 5.6               16363                    5.05
# 6                 5.0               14694                    4.57
# 7                 4.7               13643                    4.38
# 8                 4.1                9862                    3.28
# 9                 4.3                6670                    2.26
#
#    Dividends USD  Shares Mil  Operating Cash Flow USD Mil  \
# 0           1.09        3877                        26249
# 1           1.21        3670                        23643
# 2           1.46        3474                        24255
# 3           1.59        3389                        25591
# 4           1.88        3283                        23257
# 5           1.92        3243                        28564
# 6           1.96        3217                        27389
# 7           2.00        3112                        31530
# 8           2.04        3010                        28337
# 9           2.08        2945                        27753
#
#    Cap Spending USD Mil  Free Cash Flow USD Mil  Working Capital USD Mil
# 0                -12184                   14065                    -7230
# 1                -12699                   10944                    -6591
# 2                -13510                   10745                    -7325
# 3                -12898                   12693                   -11878
# 4                -13115                   10142                    -8160
# 5                -12174                   16390                    -1994
# 6                -11477                   15912                    -4380
# 7                -10619                   20911                    -9239
# 8                -10051                   18286                   -18857
# 9                -10344                   17409                   -15580
